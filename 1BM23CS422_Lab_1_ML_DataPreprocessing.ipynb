# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from scipy import stats

# %%
df1=pd.read_csv("adult.csv")
print("info:")
print(df1.info(),"\n")

print("description:")
print(df1.describe(),"\n")

print("unique value count:")
print(df1["income"].value_counts(),"\n")

print("missing vaules greater than zero:")
missing_values=df1.isnull().sum()
print(missing_values[missing_values>0])
# Out:
# info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB
# None
#
# description:
# ...

# %%
ordinal_encoder = OrdinalEncoder(categories=[["Male", "Female",]])

df_copy1 = df1
df_copy1["gender"] = ordinal_encoder.fit_transform(df_copy1[["gender"]])
print(df_copy1)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black     0.0
# ...

# %%
normalizer = MinMaxScaler()
df1[['hours-per-week']] = normalizer.fit_transform(df1[['hours-per-week']])
df1.head()
# Out:
#         age  workclass  fnlwgt     education  educational-num  \
# 0 -0.995129    Private  226802          11th                7
# 1 -0.046942    Private   89814       HS-grad                9
# 2 -0.776316  Local-gov  336951    Assoc-acdm               12
# 3  0.390683    Private  160323  Some-college               10
# 4 -1.505691          ?  103497  Some-college               10
#
#        marital-status         occupation relationship   race  gender  \
# 0       Never-married  Machine-op-inspct    Own-child  Black     0.0
# 1  Married-civ-spouse    Farming-fishing      Husband  White     0.0
# 2  Married-civ-spouse    Protective-serv      Husband  White     0.0
# 3  Married-civ-spouse  Machine-op-inspct      Husband  Black     0.0
# 4       Never-married                  ?    Own-child  White     1.0
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0        0.397959  United-States  <=50K
# ...

# %%
scaler = StandardScaler()
df1[['age']] = scaler.fit_transform(df1[['age']])
df1.head()
# Out:
#         age  workclass  fnlwgt     education  educational-num  \
# 0 -0.995129    Private  226802          11th                7
# 1 -0.046942    Private   89814       HS-grad                9
# 2 -0.776316  Local-gov  336951    Assoc-acdm               12
# 3  0.390683    Private  160323  Some-college               10
# 4 -1.505691          ?  103497  Some-college               10
#
#        marital-status         occupation relationship   race  gender  \
# 0       Never-married  Machine-op-inspct    Own-child  Black     0.0
# 1  Married-civ-spouse    Farming-fishing      Husband  White     0.0
# 2  Married-civ-spouse    Protective-serv      Husband  White     0.0
# 3  Married-civ-spouse  Machine-op-inspct      Husband  Black     0.0
# 4       Never-married                  ?    Own-child  White     1.0
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0        0.397959  United-States  <=50K
# ...

# %%
df2=pd.read_csv("Dataset_of_Diabetes.csv")
print("info:")
print(df2.info(),"\n")

print("description:")
print(df2.describe(),"\n")

print("unique value count:")
print(df2["Urea"].value_counts(),"\n")

print("missing vaules greater than zero:")
missing_values=df2.isnull().sum()
print(missing_values[missing_values>0])

ordinal_encoder = OrdinalEncoder(categories=[["M", "F","f"]])
# Fit and transform the data
df_copy = df2
df_copy["Gender"] = ordinal_encoder.fit_transform(df_copy[["Gender"]])
print(df_copy)
# Out:
# info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB
# None
#
# description:
#                 ID     No_Pation          AGE         Urea           Cr  \
# ...

# %%
normalizer = MinMaxScaler()
df2[['Cr']] = normalizer.fit_transform(df2[['Cr']])
df2.head()
# Out:
#     ID  No_Pation  Gender       AGE  Urea        Cr  HbA1c  Chol   TG  HDL  \
# 0  502      17975     1.0 -0.401144   4.7  0.050378    4.9   4.2  0.9  2.4
# 1  735      34221     0.0 -3.130017   4.5  0.070529    4.9   3.7  1.4  1.1
# 2  420      47975     1.0 -0.401144   4.7  0.050378    4.9   4.2  0.9  2.4
# 3  680      87656     1.0 -0.401144   4.7  0.050378    4.9   4.2  0.9  2.4
# 4  504      34223     0.0 -2.334096   7.1  0.050378    4.9   4.9  1.0  0.8
#
#    LDL  VLDL   BMI CLASS  hours-per-week
# 0  1.4   0.5  24.0     N        0.050378
# 1  2.1   0.6  23.0     N        0.070529
# 2  1.4   0.5  24.0     N        0.050378
# 3  1.4   0.5  24.0     N        0.050378
# 4  2.0   0.4  21.0     N        0.050378

# %%
scaler = StandardScaler()
df2[['AGE']] = scaler.fit_transform(df2[['AGE']])
df2.head()
# Out:
#     ID  No_Pation  Gender       AGE  Urea        Cr  HbA1c  Chol   TG  HDL  \
# 0  502      17975     1.0 -0.401144   4.7  0.050378    4.9   4.2  0.9  2.4
# 1  735      34221     0.0 -3.130017   4.5  0.070529    4.9   3.7  1.4  1.1
# 2  420      47975     1.0 -0.401144   4.7  0.050378    4.9   4.2  0.9  2.4
# 3  680      87656     1.0 -0.401144   4.7  0.050378    4.9   4.2  0.9  2.4
# 4  504      34223     0.0 -2.334096   7.1  0.050378    4.9   4.9  1.0  0.8
#
#    LDL  VLDL   BMI CLASS  hours-per-week
# 0  1.4   0.5  24.0     N        0.050378
# 1  2.1   0.6  23.0     N        0.070529
# 2  1.4   0.5  24.0     N        0.050378
# 3  1.4   0.5  24.0     N        0.050378
# 4  2.0   0.4  21.0     N        0.050378
